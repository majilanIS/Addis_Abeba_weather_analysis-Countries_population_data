# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
###
# Array Manipulation and Processing
###
arr = np.array([1, 2, 3, 4, 5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
print(arr.shape)
print(arr.ndim)
# Out:
# (5,)
# 1

# %%
np.sum(arr)
# Out:
# np.int64(15)

# %%
np.mean(arr)
# Out:
# np.float64(3.0)

# %%
np.median(arr)
# Out:
# np.float64(3.0)

# %%
np.max(arr)
# Out:
# np.int64(5)

# %%
np.min(arr)
# Out:
# np.int64(1)

# %%
## array Manipulation
arr2 = np.array([[1, 2, 3], [4, 5, 6]])
print(arr2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
# Create a 2D array
arr3 = np.array([[1, 2], [3, 4], [5, 6]])
print(arr3)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
#reshape
arr4 = arr3.reshape(2, 3)
print(arr4)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr5 =arr2.reshape(3, 2)
print(arr5)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
###
# Mathematical Operations and functions
###
number = np.array([1, 10, 20, 4, 5])
np.sort(number)
# Out:
# array([ 1,  4,  5, 10, 20])

# %%
np.add(120, 20)
np.multiply(100, 20)
# Out:
# np.int64(2000)

# %%
###
#Linear Algebra
###

np.dot
np.linalg.inv

# %%
###
# Radom number Generation
###

guess = np.random.random_integers(0,10)
print(guess)
# Out:
# 1
# C:\Users\cheko\AppData\Local\Temp\ipykernel_23696\2083509982.py:5: DeprecationWarning: This function is deprecated. Please call randint(0, 10 + 1) instead
#   guess = np.random.random_integers(0,10)
